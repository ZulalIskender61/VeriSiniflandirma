# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.svm import SVC 
from sklearn.neighbors import KNeighborsClassifier

# %%
EMGS1="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S1"
emgs1Dosyalar= glob.glob(EMGS1+"/*.csv")
liste=[]
for filename in emgs1Dosyalar:
    dataFrame1=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame1)

dataFrame1= pd.concat(liste, axis=1, ignore_index=True)
dataFrame1
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.001233 -0.000226 -0.000530 -0.000794 -0.000344  0.000780 -0.000533
# 1      0.001197 -0.000197 -0.000557 -0.000663 -0.000322  0.000513 -0.000676
# 2      0.001091 -0.000214 -0.000586 -0.000473 -0.000326  0.000224 -0.000782
# 3      0.000924 -0.000259 -0.000594 -0.000236 -0.000346 -0.000056 -0.000857
# 4      0.000712 -0.000303 -0.000563  0.000024 -0.000371 -0.000305 -0.000906
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000236  0.000678  0.000127  0.000655 -0.000419  0.000081 -0.000150
# 19995 -0.000318  0.000646  0.000144  0.000629 -0.000466  0.000015 -0.000146
# 19996 -0.000397  0.000564  0.000138  0.000606 -0.000537 -0.000049 -0.000145
# 19997 -0.000447  0.000455  0.000111  0.000585 -0.000595 -0.000086 -0.000149
# 19998 -0.000447  0.000343  0.000077  0.000556 -0.000602 -0.000085 -0.000158
#
# ...

# %%
EMGS2="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S2"
emgs2Dosyalar= glob.glob(EMGS2+"/*.csv")
liste=[]
for filename in emgs2Dosyalar:
    dataFrame2=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame2)

dataFrame2= pd.concat(liste, axis=1, ignore_index=True)
dataFrame2
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.000001 -0.000813  0.000016 -0.000084  0.000033 -0.000225  0.000015
# 1     -0.000149 -0.000860 -0.000065 -0.000086  0.000012 -0.000228 -0.000059
# 2     -0.000282 -0.000889 -0.000131 -0.000086  0.000030 -0.000244 -0.000130
# 3     -0.000388 -0.000884 -0.000172 -0.000079  0.000065 -0.000273 -0.000198
# 4     -0.000461 -0.000839 -0.000186 -0.000058  0.000085 -0.000309 -0.000262
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000186 -0.000148  0.000284  0.000002  0.000355  0.000240  0.000222
# 19995 -0.000260 -0.000147  0.000270  0.000024  0.000308  0.000242  0.000218
# 19996 -0.000304 -0.000143  0.000238  0.000047  0.000233  0.000241  0.000204
# 19997 -0.000323 -0.000129  0.000195  0.000068  0.000137  0.000233  0.000180
# 19998 -0.000328 -0.000107  0.000154  0.000086  0.000039  0.000215  0.000150
#
# ...

# %%
EMGS3="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S3"
emgs3Dosyalar= glob.glob(EMGS3+"/*.csv")
liste=[]
for filename in emgs3Dosyalar:
    dataFrame3=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame3)

dataFrame3= pd.concat(liste, axis=1, ignore_index=True)
dataFrame3
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.000194  0.000047 -0.000084  0.000114  0.000168  0.000049  0.000673
# 1      0.000011  0.000061 -0.000072  0.000119  0.000140  0.000076  0.000632
# 2     -0.000228  0.000067 -0.000062  0.000121  0.000073  0.000101  0.000583
# 3     -0.000460  0.000067 -0.000054  0.000121 -0.000008  0.000123  0.000530
# 4     -0.000618  0.000067 -0.000040  0.000118 -0.000075  0.000137  0.000483
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994  0.000362  0.000386  0.000614 -0.000213  0.000222  0.000340 -0.000098
# 19995  0.000395  0.000444  0.000364 -0.000289  0.000308  0.000497 -0.000194
# 19996  0.000377  0.000462  0.000076 -0.000362  0.000323  0.000605 -0.000245
# 19997  0.000302  0.000443 -0.000163 -0.000428  0.000272  0.000646 -0.000230
# 19998  0.000188  0.000395 -0.000280 -0.000481  0.000181  0.000622 -0.000160
#
# ...

# %%
EMGS4="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S4"
emgs4Dosyalar= glob.glob(EMGS4+"/*.csv")
liste=[]
for filename in emgs4Dosyalar:
    dataFrame4=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame4)

dataFrame4= pd.concat(liste, axis=1, ignore_index=True)
dataFrame4
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.001883  0.000297  0.000022  0.000922 -0.000304 -0.001082 -0.000115
# 1     -0.001850  0.000257 -0.000105  0.000843  0.000102 -0.001149 -0.000096
# 2     -0.001769  0.000215 -0.000183  0.000761  0.000426 -0.001121 -0.000084
# 3     -0.001617  0.000111 -0.000197  0.000671  0.000538 -0.001007 -0.000080
# 4     -0.001376 -0.000082 -0.000160  0.000571  0.000371 -0.000822 -0.000080
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000669 -0.000026 -0.000368 -0.000059  0.000121  0.000789  0.000089
# 19995 -0.000742 -0.000138 -0.000416 -0.000113  0.000109  0.000728  0.000100
# 19996 -0.000789 -0.000227 -0.000434 -0.000099  0.000097  0.000577  0.000103
# 19997 -0.000800 -0.000296 -0.000416 -0.000043  0.000075  0.000376  0.000098
# 19998 -0.000768 -0.000357 -0.000362  0.000002  0.000035  0.000170  0.000089
#
# ...

# %%
EMGS5="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S5"
emgs5Dosyalar= glob.glob(EMGS5+"/*.csv")
liste=[]
for filename in emgs5Dosyalar:
    dataFrame5=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame5)

dataFrame5= pd.concat(liste, axis=1, ignore_index=True)
dataFrame5
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.000016  0.000079 -0.000067  0.000002  0.000213  0.000133 -0.000648
# 1     -0.000012  0.000083  0.000076  0.000004  0.000164  0.000132 -0.000619
# 2     -0.000010  0.000087  0.000228  0.000004  0.000128  0.000123 -0.000592
# 3     -0.000010  0.000084  0.000376  0.000001  0.000098  0.000112 -0.000572
# 4     -0.000018  0.000071  0.000514 -0.000003  0.000064  0.000103 -0.000557
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994  0.000068 -0.001379  0.000029 -0.000825  0.000050 -0.000377  0.000057
# 19995  0.000095 -0.001315  0.000029 -0.000765  0.000062 -0.000333  0.000051
# 19996  0.000123 -0.001218  0.000024 -0.000715  0.000076 -0.000266  0.000042
# 19997  0.000141 -0.001091  0.000016 -0.000677  0.000095 -0.000191  0.000032
# 19998  0.000140 -0.000900  0.000009 -0.000650  0.000114 -0.000116  0.000024
#
# ...

# %%
EMGS6="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S6"
emgs6Dosyalar= glob.glob(EMGS6+"/*.csv")
liste=[]
for filename in emgs6Dosyalar:
    dataFrame6=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame6)

dataFrame6= pd.concat(liste, axis=1, ignore_index=True)
dataFrame6
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.000077 -0.000301 -0.000132 -0.000199 -0.001105  0.000100 -0.000502
# 1     -0.000090 -0.000409 -0.000169 -0.000252 -0.001087  0.000486 -0.000386
# 2     -0.000049 -0.000486 -0.000159 -0.000278 -0.000991  0.000824 -0.000324
# 3      0.000036 -0.000526 -0.000107 -0.000244 -0.000822  0.001032 -0.000306
# 4      0.000127 -0.000535 -0.000043 -0.000127 -0.000611  0.001087 -0.000306
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000684 -0.000192 -0.000189 -0.000436 -0.000056  0.000504  0.000460
# 19995 -0.000686 -0.000047 -0.000272 -0.000391 -0.000081  0.000473  0.000374
# 19996 -0.000691  0.000121 -0.000301 -0.000327 -0.000102  0.000412  0.000286
# 19997 -0.000697  0.000282 -0.000256 -0.000266 -0.000122  0.000340  0.000191
# 19998 -0.000708  0.000407 -0.000140 -0.000223 -0.000142  0.000284  0.000076
#
# ...

# %%
EMGS7="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S7"
emgs7Dosyalar= glob.glob(EMGS7+"/*.csv")
liste=[]
for filename in emgs7Dosyalar:
    dataFrame7=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame7)

dataFrame7= pd.concat(liste, axis=1, ignore_index=True)
dataFrame7
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.000647  0.001659 -0.001060  0.000024  0.000355  0.000413 -0.000852
# 1      0.000248  0.001620 -0.000987  0.000027  0.000189  0.000611 -0.000860
# 2     -0.000204  0.001459 -0.000840  0.000032 -0.000011  0.000794 -0.000819
# 3     -0.000580  0.001202 -0.000631  0.000036 -0.000225  0.000946 -0.000729
# 4     -0.000799  0.000898 -0.000388  0.000036 -0.000433  0.001047 -0.000588
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994  0.000081  0.000198  0.000089  0.000091  0.000094  0.000735 -0.000116
# 19995  0.000117  0.000166  0.000096  0.000117  0.000101  0.000413 -0.000046
# 19996  0.000140  0.000142  0.000099  0.000141  0.000101  0.000121  0.000036
# 19997  0.000144  0.000129  0.000099  0.000164  0.000090 -0.000089  0.000112
# 19998  0.000134  0.000128  0.000095  0.000190  0.000071 -0.000198  0.000164
#
# ...

# %%
EMGS8="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S8"
emgs8Dosyalar= glob.glob(EMGS8+"/*.csv")
liste=[]
for filename in emgs8Dosyalar:
    dataFrame8=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame8)

dataFrame8= pd.concat(liste, axis=1, ignore_index=True)
dataFrame8
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.000033  0.000750 -0.001074  0.000820  0.000169  0.004959 -0.000271
# 1      0.000027  0.000719 -0.001131  0.000527  0.000087  0.004959 -0.000277
# 2      0.000028  0.000648 -0.001142  0.000301  0.000085  0.004592 -0.000235
# 3      0.000044  0.000539 -0.001109  0.000158  0.000164  0.003798 -0.000153
# 4      0.000071  0.000414 -0.001032  0.000080  0.000293  0.002936 -0.000057
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994  0.000072 -0.000023  0.000043 -0.000178 -0.000048 -0.000420 -0.000040
# 19995  0.000092 -0.000036  0.000032 -0.000132 -0.000051 -0.000242 -0.000017
# 19996  0.000106 -0.000036  0.000017 -0.000076 -0.000055 -0.000060  0.000007
# 19997  0.000109 -0.000020  0.000003 -0.000008 -0.000057  0.000105  0.000026
# 19998  0.000094  0.000023 -0.000004  0.000076 -0.000055  0.000240  0.000034
#
# ...

# %%
EMGS9="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S9"
emgs9Dosyalar= glob.glob(EMGS9+"/*.csv")
liste=[]
for filename in emgs9Dosyalar:
    dataFrame9=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame9)

dataFrame9= pd.concat(liste, axis=1, ignore_index=True)
dataFrame9
# Out:
#             0         1         2             3         4         5    \
# 0      0.000211 -0.000318  0.000317 -1.577513e-04  0.000124  0.000074
# 1      0.000229 -0.000373  0.000321 -1.561307e-04  0.000121  0.000086
# 2      0.000236 -0.000418  0.000314 -1.452723e-04  0.000108  0.000092
# 3      0.000240 -0.000442  0.000301 -1.287416e-04  0.000086  0.000093
# 4      0.000245 -0.000445  0.000287 -1.122110e-04  0.000065  0.000091
# ...         ...       ...       ...           ...       ...       ...
# 19994 -0.000041  0.000032 -0.000029 -7.030578e-06  0.000066  0.000084
# 19995 -0.000028 -0.000016 -0.000027 -6.176923e-08  0.000072  0.000098
# 19996 -0.000020 -0.000065 -0.000016  1.954813e-05  0.000072  0.000110
# 19997 -0.000014 -0.000110  0.000004  5.309565e-05  0.000063  0.000119
# 19998 -0.000010 -0.000149  0.000027  9.361198e-05  0.000048  0.000122
#
#             6         7         8             9    ...       110       111  \
# ...

# %%
EMGS10="C:/Users/90537/Desktop/YapayZekaDonemProjesi/Delsys_2Chans_10Classes_10Subjects_Fingers/EMG_2Chs/EMG-S10"
emgs10Dosyalar= glob.glob(EMGS10+"/*.csv")
liste=[]
for filename in emgs10Dosyalar:
    dataFrame10=pd.read_csv(filename,index_col=None, header=0)
    liste.append(dataFrame10)

dataFrame10= pd.concat(liste, axis=1, ignore_index=True)
dataFrame10
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.000141  0.000134  0.000312  0.000071 -0.000491 -0.000785  0.000332
# 1     -0.000146  0.000081  0.000324  0.000021 -0.000394 -0.000794  0.000329
# 2     -0.000182  0.000059  0.000344 -0.000025 -0.000312 -0.000803  0.000315
# 3     -0.000234  0.000079  0.000385 -0.000061 -0.000279 -0.000828  0.000297
# 4     -0.000268  0.000144  0.000452 -0.000090 -0.000308 -0.000877  0.000278
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000279 -0.000633 -0.000282  0.000064 -0.000216  0.001142 -0.000246
# 19995 -0.000234 -0.000595 -0.000331  0.000072 -0.000085  0.001207 -0.000201
# 19996 -0.000212 -0.000512 -0.000380  0.000015  0.000029  0.001297 -0.000159
# 19997 -0.000220 -0.000415 -0.000407 -0.000109  0.000105  0.001362 -0.000146
# 19998 -0.000250 -0.000329 -0.000409 -0.000247  0.000135  0.001345 -0.000166
#
# ...

# %%
dataFrame1['sınıf']='0'
dataFrame2['sınıf']='1'
dataFrame3['sınıf']='2'
dataFrame4['sınıf']='3'
dataFrame5['sınıf']='4'
dataFrame6['sınıf']='5'
dataFrame7['sınıf']='6'
dataFrame8['sınıf']='7'
dataFrame9['sınıf']='8'
dataFrame10['sınıf']='9'

# %%
dataFrame=pd.concat([dataFrame1,dataFrame2,dataFrame3,dataFrame4,dataFrame5,dataFrame6,dataFrame7,dataFrame8,dataFrame9,dataFrame10])

# %%
dataFrame
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.001233 -0.000226 -0.000530 -0.000794 -0.000344  0.000780 -0.000533
# 1      0.001197 -0.000197 -0.000557 -0.000663 -0.000322  0.000513 -0.000676
# 2      0.001091 -0.000214 -0.000586 -0.000473 -0.000326  0.000224 -0.000782
# 3      0.000924 -0.000259 -0.000594 -0.000236 -0.000346 -0.000056 -0.000857
# 4      0.000712 -0.000303 -0.000563  0.000024 -0.000371 -0.000305 -0.000906
# ...         ...       ...       ...       ...       ...       ...       ...
# 19994 -0.000279 -0.000633 -0.000282  0.000064 -0.000216  0.001142 -0.000246
# 19995 -0.000234 -0.000595 -0.000331  0.000072 -0.000085  0.001207 -0.000201
# 19996 -0.000212 -0.000512 -0.000380  0.000015  0.000029  0.001297 -0.000159
# 19997 -0.000220 -0.000415 -0.000407 -0.000109  0.000105  0.001362 -0.000146
# 19998 -0.000250 -0.000329 -0.000409 -0.000247  0.000135  0.001345 -0.000166
#
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199990 entries, 0 to 19998
# Columns: 121 entries, 0 to sınıf
# dtypes: float64(120), object(1)
# memory usage: 186.1+ MB

# %%
dataFrame.describe().T
# Out:
#         count      mean       std       min       25%       50%       75%  \
# 0    199990.0  0.000017  0.000325 -0.004284 -0.000101  0.000031  0.000158
# 1    199990.0  0.000022  0.000536 -0.004969 -0.000191  0.000011  0.000208
# 2    199990.0  0.000017  0.000310 -0.004969 -0.000101  0.000031  0.000160
# 3    199990.0  0.000022  0.000535 -0.004969 -0.000183  0.000016  0.000203
# 4    199990.0  0.000017  0.000288 -0.004083 -0.000102  0.000031  0.000157
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  199990.0  0.000039  0.000175 -0.001565 -0.000046  0.000038  0.000119
# 116  199990.0  0.000034  0.000470 -0.004967 -0.000120  0.000050  0.000218
# 117  199990.0  0.000039  0.000179 -0.001548 -0.000046  0.000039  0.000117
# 118  199990.0  0.000034  0.000515 -0.004968 -0.000126  0.000050  0.000227
# 119  199990.0  0.000038  0.000162 -0.001084 -0.000042  0.000037  0.000114
#
#           max
# 0    0.002330
# 1    0.004959
# 2    0.003501
# 3    0.004959
# ...

# %%
dataFrame.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
y=dataFrame.sınıf.values
y=le.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
X=dataFrame.drop(["sınıf"],axis=1)

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199990 entries, 0 to 19998
# Columns: 121 entries, 0 to sınıf
# dtypes: float64(120), object(1)
# memory usage: 186.1+ MB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=44)

# %%
dataFrame.shape
# Out:
# (199990, 121)

# %%
X_train.shape
# Out:
# (139993, 120)

# %%
X_test.shape
# Out:
# (59997, 120)

# %%
y_train.shape
# Out:
# (139993,)

# %%
y_test.shape
# Out:
# (59997,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
tahmin=knn.predict(X_test)

# %%
tahmin

# %%
y_test #gerçek değerlerimiz

# %%
#sonuc=knn.score(X_test,y_test) #x_test = test datası , y_test= gerçek değer
#X_test e göre gerçekleri skorla . Kaçta kaçı doğru

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
tahmin=knn.predict(X_test)
sonuc=knn.score(X_test,y_test)
print("model başarısı= ",sonuc)
